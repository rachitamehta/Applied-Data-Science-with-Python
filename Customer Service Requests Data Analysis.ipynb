# %% [markdown]
# #### 1. Importing the required libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# #### 2. Import and understand the dataset

# %%
nyc = pd.read_csv("/Users/macuser/Documents/PGP AI & ML/Applied DS with Python/Customer_Service_Requests_Analysis_Dataset/311_Service_Requests_from_2010_to_Present.csv")
nyc
# Out:
#         Unique Key            Created Date             Closed Date Agency  \
# 0         32310363  12/31/2015 11:59:45 PM  01/01/2016 12:55:15 AM   NYPD
# 1         32309934  12/31/2015 11:59:44 PM  01/01/2016 01:26:57 AM   NYPD
# 2         32309159  12/31/2015 11:59:29 PM  01/01/2016 04:51:03 AM   NYPD
# 3         32305098  12/31/2015 11:57:46 PM  01/01/2016 07:43:13 AM   NYPD
# 4         32306529  12/31/2015 11:56:58 PM  01/01/2016 03:24:42 AM   NYPD
# ...            ...                     ...                     ...    ...
# 364553    29609918  01/01/2015 12:04:44 AM  01/01/2015 10:22:31 AM   NYPD
# 364554    29608392  01/01/2015 12:04:28 AM  01/01/2015 02:25:02 AM   NYPD
# 364555    29607589  01/01/2015 12:01:30 AM  01/01/2015 12:20:33 AM   NYPD
# 364556    29610889  01/01/2015 12:01:29 AM  01/01/2015 02:42:22 AM   NYPD
# 364557    29611816  01/01/2015 12:00:50 AM  01/01/2015 02:47:50 AM   NYPD
#
#                             Agency Name           Complaint Type  \
# ...

# %%
nyc = pd.read_csv("/Users/macuser/Documents/PGP AI & ML/Applied DS with Python/Customer_Service_Requests_Analysis_Dataset/311_Service_Requests_from_2010_to_Present.csv", parse_dates=['Created Date', 'Closed Date'])
nyc
# Out:
#         Unique Key        Created Date         Closed Date Agency  \
# 0         32310363 2015-12-31 23:59:45 2016-01-01 00:55:15   NYPD
# 1         32309934 2015-12-31 23:59:44 2016-01-01 01:26:57   NYPD
# 2         32309159 2015-12-31 23:59:29 2016-01-01 04:51:03   NYPD
# 3         32305098 2015-12-31 23:57:46 2016-01-01 07:43:13   NYPD
# 4         32306529 2015-12-31 23:56:58 2016-01-01 03:24:42   NYPD
# ...            ...                 ...                 ...    ...
# 364553    29609918 2015-01-01 00:04:44 2015-01-01 10:22:31   NYPD
# 364554    29608392 2015-01-01 00:04:28 2015-01-01 02:25:02   NYPD
# 364555    29607589 2015-01-01 00:01:30 2015-01-01 00:20:33   NYPD
# 364556    29610889 2015-01-01 00:01:29 2015-01-01 02:42:22   NYPD
# 364557    29611816 2015-01-01 00:00:50 2015-01-01 02:47:50   NYPD
#
#                             Agency Name           Complaint Type  \
# 0       New York City Police Department  Noise - Street/Sidewalk
# ...

# %%
nyc.shape
# Out:
# (364558, 53)

# %%
nyc.isnull()
# Out:
#         Unique Key  Created Date  Closed Date  Agency  Agency Name  \
# 0            False         False        False   False        False
# 1            False         False        False   False        False
# 2            False         False        False   False        False
# 3            False         False        False   False        False
# 4            False         False        False   False        False
# ...            ...           ...          ...     ...          ...
# 364553       False         False        False   False        False
# 364554       False         False        False   False        False
# 364555       False         False        False   False        False
# 364556       False         False        False   False        False
# 364557       False         False        False   False        False
#
#         Complaint Type  Descriptor  Location Type  Incident Zip  \
# 0                False       False          False         False
# ...

# %%
nyc.isnull().any()
# Out:
# Unique Key                        False
# Created Date                      False
# Closed Date                        True
# Agency                            False
# Agency Name                       False
# Complaint Type                    False
# Descriptor                         True
# Location Type                      True
# Incident Zip                       True
# Incident Address                   True
# Street Name                        True
# Cross Street 1                     True
# Cross Street 2                     True
# Intersection Street 1              True
# Intersection Street 2              True
# Address Type                       True
# City                               True
# Landmark                           True
# Facility Type                      True
# Status                            False
# Due Date                           True
# Resolution Description            False
# Resolution Action Updated Date     True
# ...

# %%
nyc.isnull().sum()
# Out:
# Unique Key                             0
# Created Date                           0
# Closed Date                         2381
# Agency                                 0
# Agency Name                            0
# Complaint Type                         0
# Descriptor                          6501
# Location Type                        133
# Incident Zip                        2998
# Incident Address                   51699
# Street Name                        51699
# Cross Street 1                     57188
# Cross Street 2                     57805
# Intersection Street 1             313438
# Intersection Street 2             314046
# Address Type                        3252
# City                                2997
# Landmark                          364183
# Facility Type                       2389
# Status                                 0
# Due Date                               3
# Resolution Description                 0
# Resolution Action Updated Date      2402
# ...

# %%
nyc.isnull().sum().plot.bar(figsize=(12,6))
plt.ylabel('Total missing values')
plt.xlabel('Variables')
plt.title('Visualizing the missing data')
# Out:
# Text(0.5, 1.0, 'Visualizing the missing data')

# %% [markdown]
# #### 3. Missing Value Treatment:
# 1. Drop the missing values
# 2. Fill the missing values with fixed value
# 3. Fill the missing values with mean, median and mode

# %% [markdown]
# - Looking at the bar graph, most of the missing values are from categorical variables. Since there are multiple variables with many missing values, the missing values will not be dropped all across as it would lead to data loss.
# - Closed Date missing values can be dropped from the dataset since it is a small number.

# %%
# Creating a copy of the dataset 

nyc1 = nyc.copy()
nyc1
# Out:
#         Unique Key        Created Date         Closed Date Agency  \
# 0         32310363 2015-12-31 23:59:45 2016-01-01 00:55:15   NYPD
# 1         32309934 2015-12-31 23:59:44 2016-01-01 01:26:57   NYPD
# 2         32309159 2015-12-31 23:59:29 2016-01-01 04:51:03   NYPD
# 3         32305098 2015-12-31 23:57:46 2016-01-01 07:43:13   NYPD
# 4         32306529 2015-12-31 23:56:58 2016-01-01 03:24:42   NYPD
# ...            ...                 ...                 ...    ...
# 364553    29609918 2015-01-01 00:04:44 2015-01-01 10:22:31   NYPD
# 364554    29608392 2015-01-01 00:04:28 2015-01-01 02:25:02   NYPD
# 364555    29607589 2015-01-01 00:01:30 2015-01-01 00:20:33   NYPD
# 364556    29610889 2015-01-01 00:01:29 2015-01-01 02:42:22   NYPD
# 364557    29611816 2015-01-01 00:00:50 2015-01-01 02:47:50   NYPD
#
#                             Agency Name           Complaint Type  \
# 0       New York City Police Department  Noise - Street/Sidewalk
# ...

# %%
nyc1.dropna(subset = ['Closed Date'],inplace=True)

# %%
nyc1.isna().sum()
# Out:
# Unique Key                             0
# Created Date                           0
# Closed Date                            0
# Agency                                 0
# Agency Name                            0
# Complaint Type                         0
# Descriptor                          6496
# Location Type                        130
# Incident Zip                         675
# Incident Address                   51686
# Street Name                        51686
# Cross Street 1                     55331
# Cross Street 2                     55464
# Intersection Street 1             311549
# Intersection Street 2             311673
# Address Type                         929
# City                                 674
# Landmark                          361802
# Facility Type                         18
# Status                                 0
# Due Date                               1
# Resolution Description                 0
# Resolution Action Updated Date        39
# ...

# %% [markdown]
# ### Exploratory Data Analysis

# %% [markdown]
# #### Exploring Date / Time
#
# Analyze the date column and remove entries that have an incorrect timeline

# %%
nyc1.columns= nyc1.columns.str.replace(" ", "_")

# %%
a=(nyc1.Created_Date[0] - nyc1.Closed_Date[0] )
a.seconds
# Out:
# 83070

# %%
nyc1['Request_Closing_Time']=  nyc1.Closed_Date - nyc1.Created_Date

# %%
nyc1['Request_Closing_Time'].head()
# Out:
# 0   0 days 00:55:30
# 1   0 days 01:27:13
# 2   0 days 04:51:34
# 3   0 days 07:45:27
# 4   0 days 03:27:44
# Name: Request_Closing_Time, dtype: timedelta64[ns]

# %%
nyc1[['City', 'Complaint_Type']].isnull().sum()
# Out:
# City              674
# Complaint_Type      0
# dtype: int64

# %%
nyc1['City'].fillna('Unknown City', inplace= True)

# %%
nyc1[['City', 'Complaint_Type']].isnull().sum()
# Out:
# City              0
# Complaint_Type    0
# dtype: int64

# %% [markdown]
# #### Frequency plot for city-wise complaints

# %%
sns.set()
nyc1['City'].value_counts().sort_values(ascending= True).plot(kind= 'barh', figsize=(17,20), title="Frequency plot for city-wise complaints")
plt.xlabel('Complaint Count')
plt.ylabel('City')
plt.show()

# %% [markdown]
# #### Scatter and Hexbin Plot for complaints concentrated across Brooklyn

# %%
brooklyn_data = nyc1[nyc1['City']=='BROOKLYN']

# %%
brooklyn_data[['Longitude', 'Latitude']].plot(kind='scatter', 
                                         x='Longitude', 
                                         y='Latitude', 
                                         figsize=(15,10), 
                                         title = 'Complaints Concentration Across Brooklyn'
                                        ).axis('equal')
plt.xlabel('Longitude')
plt.ylabel('Latitude')
plt.show()
# Out:
# *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2-D array with a single row if you intend to specify the same RGB or RGBA value for all points.

# %%
brooklyn_data.plot(kind='hexbin', 
              x='Longitude', 
              y='Latitude', 
              gridsize=40,
              colormap = 'jet',
              mincnt=1,
              title = 'Complaints concentration across Brooklyn',
              figsize=(15,10)
             ).axis('equal')
plt.xlabel('Longitude')
plt.ylabel('Latitude')
plt.show()

# %% [markdown]
# ### Major Types of Complaints

# %% [markdown]
# #### Bar Graph of count vs complaint type

# %%
sns.set()
nyc1['Complaint_Type'].value_counts().plot(kind= 'bar', figsize=(20,10), title="Complaint Count")
plt.xlabel('Complaint Type')
plt.ylabel('Complaint Count')
plt.show()

# %%
nyc1['City'].unique()
# Out:
# array(['NEW YORK', 'ASTORIA', 'BRONX', 'ELMHURST', 'BROOKLYN',
#        'KEW GARDENS', 'JACKSON HEIGHTS', 'MIDDLE VILLAGE', 'REGO PARK',
#        'SAINT ALBANS', 'JAMAICA', 'SOUTH RICHMOND HILL', 'Unknown City',
#        'RIDGEWOOD', 'HOWARD BEACH', 'FOREST HILLS', 'STATEN ISLAND',
#        'OZONE PARK', 'RICHMOND HILL', 'WOODHAVEN', 'FLUSHING', 'CORONA',
#        'QUEENS VILLAGE', 'OAKLAND GARDENS', 'HOLLIS', 'MASPETH',
#        'EAST ELMHURST', 'SOUTH OZONE PARK', 'WOODSIDE', 'FRESH MEADOWS',
#        'LONG ISLAND CITY', 'ROCKAWAY PARK', 'SPRINGFIELD GARDENS',
#        'COLLEGE POINT', 'BAYSIDE', 'GLEN OAKS', 'FAR ROCKAWAY',
#        'BELLEROSE', 'LITTLE NECK', 'CAMBRIA HEIGHTS', 'ROSEDALE',
#        'SUNNYSIDE', 'WHITESTONE', 'ARVERNE', 'FLORAL PARK',
#        'NEW HYDE PARK', 'CENTRAL PARK', 'BREEZY POINT', 'QUEENS',
#        'Astoria', 'Long Island City', 'Woodside', 'East Elmhurst',
#        'Howard Beach'], dtype=object)

# %% [markdown]
# #### Top 10 types of complaints

# %%
nyc1['Complaint_Type'].value_counts()[0:10]
# Out:
# Blocked Driveway           100624
# Illegal Parking             91716
# Noise - Street/Sidewalk     51139
# Noise - Commercial          43751
# Derelict Vehicle            21518
# Noise - Vehicle             19301
# Animal Abuse                10530
# Traffic                      5196
# Homeless Encampment          4879
# Vending                      4185
# Name: Complaint_Type, dtype: int64

# %%
top_10= np.array(nyc1['Complaint_Type'].value_counts()[0:10].index)
top_10
# Out:
# array(['Blocked Driveway', 'Illegal Parking', 'Noise - Street/Sidewalk',
#        'Noise - Commercial', 'Derelict Vehicle', 'Noise - Vehicle',
#        'Animal Abuse', 'Traffic', 'Homeless Encampment', 'Vending'],
#       dtype=object)

# %%
nyc1_complaints= pd.DataFrame()

for i in nyc1['City'].unique():
    nyc1_complaints[i]= nyc1.loc[nyc1['City']== i]['Complaint_Type'].value_counts()

# %%
nyc1_complaints.head()
# Out:
#                          NEW YORK  ASTORIA   BRONX  ELMHURST  BROOKLYN  \
# Noise - Street/Sidewalk     22245    409.0  9144.0     228.0   13982.0
# Noise - Commercial          18686   1653.0  2944.0      85.0   13855.0
# Illegal Parking             14549   1340.0  9889.0     760.0   33532.0
# Noise - Vehicle              6294    236.0  3556.0      69.0    5965.0
# Homeless Encampment          3060     32.0   275.0      34.0     948.0
#
#                          KEW GARDENS  JACKSON HEIGHTS  MIDDLE VILLAGE  \
# Noise - Street/Sidewalk         13.0            238.0            38.0
# Noise - Commercial             203.0            619.0            13.0
# Illegal Parking                276.0            240.0          1104.0
# Noise - Vehicle                 23.0             75.0            45.0
# Homeless Encampment              5.0             11.0             5.0
#
#                          REGO PARK  SAINT ALBANS  ...  FLORAL PARK  \
# ...

# %% [markdown]
# ### Visualize major types of complaints in each city

# %%
sns.set()
nyc1_complaints.T.plot(kind= 'bar', stacked= True, figsize= (30, 25), title="City-wise Complaints")
plt.xlabel('Complaint Count')
plt.ylabel('City')
plt.show()
